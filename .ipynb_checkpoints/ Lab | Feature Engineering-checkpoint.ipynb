# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# Load the dataset
file_path = '/Users/henriettaokoli/Downloads/learningSet.csv'  # Ensure this path is correct
data = pd.read_csv(file_path)  # Use a comma here, not a semicolon

# Display the first few rows of the dataset
print(data.head())
# Out:
# /var/folders/r7/z9gb1qsn1s19784msdjpwrzh0000gn/T/ipykernel_50494/3586117784.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)  # Use a comma here, not a semicolon
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0     8901     GRI      0    IL  61081                    3712      0
# 1     9401     BOA      1    CA  91326                    5202      0
# 2     9001     AMH      1    NC  27017                       0      0
# 3     8701     BRY      0    CA  95953                    2801      0
# 4     8601              0    FL  33176                    2001      0
#
#   RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# 0           ...      0.0        0      L      4      E        X         X
# 1           ...      0.0        0      L      2      G        X         X
# 2           ...      0.0        1      L      4      E        X         X
# ...

# %%
file_path = '/Users/henriettaokoli/Downloads/learningSet.csv'

# %%
data = pd.read_csv(file_path, low_memory=False)

# %%
print(data.head())
# Out:
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0     8901     GRI      0    IL  61081                    3712      0
# 1     9401     BOA      1    CA  91326                    5202      0
# 2     9001     AMH      1    NC  27017                       0      0
# 3     8701     BRY      0    CA  95953                    2801      0
# 4     8601              0    FL  33176                    2001      0
#
#   RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# 0           ...      0.0        0      L      4      E        X         X
# 1           ...      0.0        0      L      2      G        X         X
# 2           ...      0.0        1      L      4      E        X         X
# 3           ...      0.0        1      L      4      E        X         X
# 4        X  ...      0.0        1      L      2      F        X         X
#
#   MDMAUD_A CLUSTER2 GEOCODE2
# 0        X     39.0        C
# 1        X      1.0        A
# ...

# %%
print(f"DataFrame shape: {data.shape}")
# Out:
# DataFrame shape: (95412, 481)

# %%
print(data.dtypes)
# Out:
# ODATEDW       int64
# OSOURCE      object
# TCODE         int64
# STATE        object
# ZIP          object
#              ...
# MDMAUD_R     object
# MDMAUD_F     object
# MDMAUD_A     object
# CLUSTER2    float64
# GEOCODE2     object
# Length: 481, dtype: object

# %%
print(data.isnull().sum())
# Out:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2    132
# Length: 481, dtype: int64

# %%
print(data.describe())
# Out:
#             ODATEDW         TCODE           DOB           AGE       NUMCHLD  \
# count  95412.000000  95412.000000  95412.000000  71747.000000  12386.000000
# mean    9141.363256     54.223117   2723.602933     61.611649      1.527773
# std      343.454752    953.844476   2132.241295     16.664199      0.806861
# min     8306.000000      0.000000      0.000000      1.000000      1.000000
# 25%     8801.000000      0.000000    201.000000     48.000000      1.000000
# 50%     9201.000000      1.000000   2610.000000     62.000000      1.000000
# 75%     9501.000000      2.000000   4601.000000     75.000000      2.000000
# max     9701.000000  72002.000000   9710.000000     98.000000      7.000000
#
#              INCOME       WEALTH1           HIT       MBCRAFT      MBGARDEN  \
# count  74126.000000  50680.000000  95412.000000  42558.000000  42558.000000
# mean       3.886248      5.345699      3.321438      0.152075      0.059166
# ...

# %%
data['GEOCODE2'].fillna('Unknown', inplace=True)

# %%
print(data['WEALTH1'].unique())
# Out:
# [nan  9.  1.  4.  2.  6.  0.  5.  8.  3.  7.]

# %%
data['ADI'].fillna(data['ADI'].median(), inplace=True)

# %%
print(data['DMA'].unique())
# Out:
# [682. 803. 518. 862. 528. 691. 509. 643. 624. 659. 671. 527. 613. 716.
#  770. 505. 717. 534. 560. 547. 571. 602. 800. 638. 618. 609. 820. 821.
#  635. 675. 563. 819. 617. 637. 606. 709. 632. 807. 698. 623. 507. 627.
#  524. 517. 539. 649. 868. 546. 529. 567. 825. 512. 669. 764. 575. 548.
#  662. 811. 801. 652. 771. 603. 556. 622. 561. 724. 804. 633. 839. 686.
#  650. 743. 619. 678. 753. 610. 745. 604. 749. 670. 765. 711. 553. 762.
#  520. 503. 551. 515. 647. 544.   0. 676. 752. 545. 754. 810. 790. 656.
#  755. 641. 616. 628. 588. 581. 540. 658. 583. 866. 642. 746. 634. 648.
#  705. 725. 744. 513. 612. 813. 531. 751. 500. 630. 611. 789. 582. 693.
#  692. 828. 626. 710. 542. 855. 687. 679. 640. 722. 620. 881. 564. 522.
#  756. 570. 718.  nan 530. 557. 625. 541. 657. 631. 550. 525. 605. 773.
#  519. 535. 600. 734. 759. 757. 511. 798. 802. 644. 651. 702. 737. 767.
#  673. 736. 636. 592. 758. 504. 639. 501. 506. 523. 760. 766. 646. 740.
# ...

# %%
print(data['MSA'].unique())
# Out:
# [   0. 4480. 9340. 5000. 2030. 3960. 5360. 3480.  760. 2160. 5960. 5120.
#   440. 6580. 1600.  680. 3360. 7040. 2920. 3120. 6440.  640. 6120. 3000.
#  7600. 2680. 5080. 1360. 2180. 4420. 1960. 6640. 7360. 5945. 1920. 1145.
#  7520. 2800. 1520. 7510. 1620. 4520. 7320.  720. 4720. 1560. 8960.   40.
#  6720.  520. 9360. 3710. 8280. 6760. 3160. 5560. 3600. 6780. 5800. 4120.
#  5160. 5880.  380. 3440. 2710. 2020. 9040. 6200. 6880. 6920. 2760. 7080.
#  4080. 2580. 4100. 5790. 4200.  600. 4680. 4040. 1640. 5775. 8720. 3980.
#  2240. 1720. 5910. 9260.  200. 7400. 1020. 3290. 2720. 7240. 3800. 8120.
#   870. 2320. 3760. 1040. 2840. 3880.  920. 6080.  460.  320. 1400. 3320.
#  2640. 8200. 4890. 3660. 2670. 1000. 2520. 2440. 8520. 3720. 2080. 7500.
#  3920. 1125. 4400.  840. 7485. 8750. 8735. 1150. 5280. 3285. 7460. 2620.
#  7160. 4920. 8600.  880. 2985. 5920. 2655. 3560.   nan 3500. 7720. 7480.
#   860. 2330. 7680. 5200. 3400. 3605. 2750. 8240. 3080. 5170. 3150.  480.
# ...

# %%
print(data.isnull().sum())
# Out:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2      0
# Length: 481, dtype: int64

# %%
sns.histplot(data['ADI'], bins=30, kde=True)
plt.title('Distribution of ADI')
plt.xlabel('ADI')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data['ADI'], bins=30, kde=True)
plt.title('Distribution of ADI')
plt.xlabel('ADI')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))  # Set figure size
sns.countplot(data=data, x='WEALTH1', order=data['WEALTH1'].value_counts().index)
plt.title('Counts of Wealth Categories')
plt.xlabel('Wealth Category')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
print("Checking for infinite values in the DataFrame:")
print((data == float('inf')).sum())  # Count of positive infinity in each column
print((data == float('-inf')).sum())  # Count of negative infinity in each column
# Out:
# Checking for infinite values in the DataFrame:
# ODATEDW     0
# OSOURCE     0
# TCODE       0
# STATE       0
# ZIP         0
#            ..
# MDMAUD_R    0
# MDMAUD_F    0
# MDMAUD_A    0
# CLUSTER2    0
# GEOCODE2    0
# Length: 481, dtype: int64
# ODATEDW     0
# OSOURCE     0
# TCODE       0
# STATE       0
# ZIP         0
#            ..
# MDMAUD_R    0
# MDMAUD_F    0
# MDMAUD_A    0
# CLUSTER2    0
# GEOCODE2    0
# Length: 481, dtype: int64

# %%
data.replace([float('inf'), float('-inf')], pd.NA, inplace=True)  # Convert inf values to NaN
